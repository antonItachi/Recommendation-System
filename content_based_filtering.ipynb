# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
from tqdm import tqdm
import warnings

plt.style.use("fivethirtyeight")
warnings.filterwarnings("ignore")

# %%
movies_md = pd.read_csv("data/movies_metadata.csv")
movies_keywords = pd.read_csv("data/keywords.csv")
movies_credits = pd.read_csv("data/credits.csv")

# %%
movies_md.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45466 non-null  object
#  1   belongs_to_collection  4494 non-null   object
#  2   budget                 45466 non-null  object
#  3   genres                 45466 non-null  object
#  4   homepage               7782 non-null   object
#  5   id                     45466 non-null  object
#  6   imdb_id                45449 non-null  object
#  7   original_language      45455 non-null  object
#  8   original_title         45466 non-null  object
#  9   overview               44512 non-null  object
#  10  popularity             45461 non-null  object
#  11  poster_path            45080 non-null  object
#  12  production_companies   45463 non-null  object
#  13  production_countries   45463 non-null  object
#  14  release_date           45379 non-null  object
#  15  revenue                45460 non-null  float64
#  16  runtime                45203 non-null  float64
#  17  spoken_languages       45460 non-null  object
#  18  status                 45379 non-null  object
#  19  tagline                20412 non-null  object
#  20  title                  45460 non-null  object
#  21  video                  45460 non-null  object
#  22  vote_average           45460 non-null  float64
#  23  vote_count             45460 non-null  float64
# dtypes: float64(4), object(20)
# memory usage: 8.3+ MB

# %%
movies_keywords.head()
# Out:
#       id                                           keywords
# 0    862  [{'id': 931, 'name': 'jealousy'}, {'id': 4290,...
# 1   8844  [{'id': 10090, 'name': 'board game'}, {'id': 1...
# 2  15602  [{'id': 1495, 'name': 'fishing'}, {'id': 12392...
# 3  31357  [{'id': 818, 'name': 'based on novel'}, {'id':...
# 4  11862  [{'id': 1009, 'name': 'baby'}, {'id': 1599, 'n...

# %%
movies_credits.head()
# Out:
#                                                 cast  \
# 0  [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1  [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2  [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3  [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 4  [{'cast_id': 1, 'character': 'George Banks', '...
#
#                                                 crew     id
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...    862
# 1  [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...   8844
# 2  [{'credit_id': '52fe466a9251416c75077a89', 'de...  15602
# 3  [{'credit_id': '52fe44779251416c91011acb', 'de...  31357
# 4  [{'credit_id': '52fe44959251416c75039ed7', 'de...  11862

# %%
movies_md = movies_md[movies_md['vote_count'] >= 1500]

# %%
movies_md = movies_md[['id', 'original_title', 'overview', 'genres']]

# %%
movies_md.head()
# Out:
#       id  original_title                                           overview  \
# 0    862       Toy Story  Led by Woody, Andy's toys live happily in his ...
# 1   8844         Jumanji  When siblings Judy and Peter discover an encha...
# 5    949            Heat  Obsessive master thief, Neil McCauley leads a ...
# 31    63  Twelve Monkeys  In the year 2035, convict James Cole reluctant...
# 46   807           Se7en  Two homicide detectives are on a desperate hun...
#
#                                                genres
# 0   [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1   [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 5   [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 31  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 46  [{'id': 80, 'name': 'Crime'}, {'id': 9648, 'na...

# %%
movies_md['title'] = movies_md['original_title']
movies_md = movies_md[movies_md['id'].str.isnumeric()]
movies_md['id'] = movies_md['id'].astype(int)
movies_df = pd.merge(movies_md, movies_keywords, on='id', how='left')

# %%
movies_df.head()
# Out:
#      id  original_title                                           overview  \
# 0   862       Toy Story  Led by Woody, Andy's toys live happily in his ...
# 1  8844         Jumanji  When siblings Judy and Peter discover an encha...
# 2   949            Heat  Obsessive master thief, Neil McCauley leads a ...
# 3    63  Twelve Monkeys  In the year 2035, convict James Cole reluctant...
# 4   807           Se7en  Two homicide detectives are on a desperate hun...
#
#                                               genres           title  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...       Toy Story
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...         Jumanji
# 2  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...            Heat
# 3  [{'id': 878, 'name': 'Science Fiction'}, {'id'...  Twelve Monkeys
# 4  [{'id': 80, 'name': 'Crime'}, {'id': 9648, 'na...           Se7en
#
#                                             keywords
# 0  [{'id': 931, 'name': 'jealousy'}, {'id': 4290,...
# 1  [{'id': 10090, 'name': 'board game'}, {'id': 1...
# 2  [{'id': 642, 'name': 'robbery'}, {'id': 703, '...
# 3  [{'id': 222, 'name': 'schizophrenia'}, {'id': ...
# 4  [{'id': 476, 'name': 'self-fulfilling prophecy...

# %%
movies_df.reset_index(inplace=True, drop=True)
movies_df.head()
# Out:
#      id  original_title                                           overview  \
# 0   862       Toy Story  Led by Woody, Andy's toys live happily in his ...
# 1  8844         Jumanji  When siblings Judy and Peter discover an encha...
# 2   949            Heat  Obsessive master thief, Neil McCauley leads a ...
# 3    63  Twelve Monkeys  In the year 2035, convict James Cole reluctant...
# 4   807           Se7en  Two homicide detectives are on a desperate hun...
#
#                                               genres           title  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...       Toy Story
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...         Jumanji
# 2  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...            Heat
# 3  [{'id': 878, 'name': 'Science Fiction'}, {'id'...  Twelve Monkeys
# 4  [{'id': 80, 'name': 'Crime'}, {'id': 9648, 'na...           Se7en
#
#                                             keywords
# 0  [{'id': 931, 'name': 'jealousy'}, {'id': 4290,...
# 1  [{'id': 10090, 'name': 'board game'}, {'id': 1...
# 2  [{'id': 642, 'name': 'robbery'}, {'id': 703, '...
# 3  [{'id': 222, 'name': 'schizophrenia'}, {'id': ...
# 4  [{'id': 476, 'name': 'self-fulfilling prophecy...

# %%
movies_df['genre'] = movies_df['genres'].apply(lambda x: [i['name'] for i in eval(x)])
movies_df.head()
# Out:
#      id  original_title                                           overview  \
# 0   862       Toy Story  Led by Woody, Andy's toys live happily in his ...
# 1  8844         Jumanji  When siblings Judy and Peter discover an encha...
# 2   949            Heat  Obsessive master thief, Neil McCauley leads a ...
# 3    63  Twelve Monkeys  In the year 2035, convict James Cole reluctant...
# 4   807           Se7en  Two homicide detectives are on a desperate hun...
#
#                                               genres           title  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...       Toy Story
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...         Jumanji
# 2  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...            Heat
# 3  [{'id': 878, 'name': 'Science Fiction'}, {'id'...  Twelve Monkeys
# 4  [{'id': 80, 'name': 'Crime'}, {'id': 9648, 'na...           Se7en
#
#                                             keywords  \
# 0  [{'id': 931, 'name': 'jealousy'}, {'id': 4290,...
# 1  [{'id': 10090, 'name': 'board game'}, {'id': 1...
# 2  [{'id': 642, 'name': 'robbery'}, {'id': 703, '...
# 3  [{'id': 222, 'name': 'schizophrenia'}, {'id': ...
# 4  [{'id': 476, 'name': 'self-fulfilling prophecy...
#
#                                   genre
# 0           [Animation, Comedy, Family]
# 1          [Adventure, Fantasy, Family]
# 2      [Action, Crime, Drama, Thriller]
# 3  [Science Fiction, Thriller, Mystery]
# 4            [Crime, Mystery, Thriller]

# %%
movies_df['genre'] = movies_df['genre'].apply(lambda x: [i.replace(" ", "") for i in x])

# %%
movies_df.head()
# Out:
#      id  original_title                                           overview  \
# 0   862       Toy Story  Led by Woody, Andy's toys live happily in his ...
# 1  8844         Jumanji  When siblings Judy and Peter discover an encha...
# 2   949            Heat  Obsessive master thief, Neil McCauley leads a ...
# 3    63  Twelve Monkeys  In the year 2035, convict James Cole reluctant...
# 4   807           Se7en  Two homicide detectives are on a desperate hun...
#
#                                               genres           title  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...       Toy Story
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...         Jumanji
# 2  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...            Heat
# 3  [{'id': 878, 'name': 'Science Fiction'}, {'id'...  Twelve Monkeys
# 4  [{'id': 80, 'name': 'Crime'}, {'id': 9648, 'na...           Se7en
#
#                                             keywords  \
# 0  [{'id': 931, 'name': 'jealousy'}, {'id': 4290,...
# 1  [{'id': 10090, 'name': 'board game'}, {'id': 1...
# 2  [{'id': 642, 'name': 'robbery'}, {'id': 703, '...
# 3  [{'id': 222, 'name': 'schizophrenia'}, {'id': ...
# 4  [{'id': 476, 'name': 'self-fulfilling prophecy...
#
#                                  genre
# 0          [Animation, Comedy, Family]
# 1         [Adventure, Fantasy, Family]
# 2     [Action, Crime, Drama, Thriller]
# 3  [ScienceFiction, Thriller, Mystery]
# 4           [Crime, Mystery, Thriller]

# %%
movies_df.isnull().sum()
# Out:
# id                0
# original_title    0
# overview          0
# genres            0
# title             0
# keywords          0
# genre             0
# dtype: int64

# %%
movies_df['keywords'].fillna('[]', inplace=True)
movies_df['genre'] = movies_df['genre'].apply(lambda x: ' '.join(x))

# %%
movies_df.head()
# Out:
#      id  original_title                                           overview  \
# 0   862       Toy Story  Led by Woody, Andy's toys live happily in his ...
# 1  8844         Jumanji  When siblings Judy and Peter discover an encha...
# 2   949            Heat  Obsessive master thief, Neil McCauley leads a ...
# 3    63  Twelve Monkeys  In the year 2035, convict James Cole reluctant...
# 4   807           Se7en  Two homicide detectives are on a desperate hun...
#
#                                               genres           title  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...       Toy Story
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...         Jumanji
# 2  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...            Heat
# 3  [{'id': 878, 'name': 'Science Fiction'}, {'id'...  Twelve Monkeys
# 4  [{'id': 80, 'name': 'Crime'}, {'id': 9648, 'na...           Se7en
#
#                                             keywords  \
# 0  [{'id': 931, 'name': 'jealousy'}, {'id': 4290,...
# 1  [{'id': 10090, 'name': 'board game'}, {'id': 1...
# 2  [{'id': 642, 'name': 'robbery'}, {'id': 703, '...
# 3  [{'id': 222, 'name': 'schizophrenia'}, {'id': ...
# 4  [{'id': 476, 'name': 'self-fulfilling prophecy...
#
#                              genre
# 0          Animation Comedy Family
# 1         Adventure Fantasy Family
# 2      Action Crime Drama Thriller
# 3  ScienceFiction Thriller Mystery
# 4           Crime Mystery Thriller

# %%
movies_df.drop('genres', axis=1, inplace=True)
movies_df.head()
# Out:
#      id  original_title                                           overview  \
# 0   862       Toy Story  Led by Woody, Andy's toys live happily in his ...
# 1  8844         Jumanji  When siblings Judy and Peter discover an encha...
# 2   949            Heat  Obsessive master thief, Neil McCauley leads a ...
# 3    63  Twelve Monkeys  In the year 2035, convict James Cole reluctant...
# 4   807           Se7en  Two homicide detectives are on a desperate hun...
#
#             title                                           keywords  \
# 0       Toy Story  [{'id': 931, 'name': 'jealousy'}, {'id': 4290,...
# 1         Jumanji  [{'id': 10090, 'name': 'board game'}, {'id': 1...
# 2            Heat  [{'id': 642, 'name': 'robbery'}, {'id': 703, '...
# 3  Twelve Monkeys  [{'id': 222, 'name': 'schizophrenia'}, {'id': ...
# 4           Se7en  [{'id': 476, 'name': 'self-fulfilling prophecy...
#
#                              genre
# 0          Animation Comedy Family
# 1         Adventure Fantasy Family
# 2      Action Crime Drama Thriller
# 3  ScienceFiction Thriller Mystery
# 4           Crime Mystery Thriller

# %%
movies_df = pd.merge(movies_df, movies_credits, on='id', how='left')
movies_df.reset_index(inplace=True, drop=True)
movies_df
# Out:
#          id                  original_title  \
# 0       862                       Toy Story
# 1      8844                         Jumanji
# 2       949                            Heat
# 3        63                  Twelve Monkeys
# 4       807                           Se7en
# ..      ...                             ...
# 740  337339         The Fate of the Furious
# 741  339403                     Baby Driver
# 742  324852                 Despicable Me 3
# 743  281338  War for the Planet of the Apes
# 744  374720                         Dunkirk
#
#                                               overview  \
# 0    Led by Woody, Andy's toys live happily in his ...
# 1    When siblings Judy and Peter discover an encha...
# 2    Obsessive master thief, Neil McCauley leads a ...
# 3    In the year 2035, convict James Cole reluctant...
# 4    Two homicide detectives are on a desperate hun...
# ..                                                 ...
# 740  When a mysterious woman seduces Dom into the w...
# 741  After being coerced into working for a crime b...
# 742  Gru and his wife Lucy must stop former '80s ch...
# 743  Caesar and his apes are forced into a deadly c...
# 744  The miraculous evacuation of Allied soldiers f...
#
#                               title  \
# 0                         Toy Story
# 1                           Jumanji
# 2                              Heat
# 3                    Twelve Monkeys
# 4                             Se7en
# ..                              ...
# 740         The Fate of the Furious
# 741                     Baby Driver
# 742                 Despicable Me 3
# 743  War for the Planet of the Apes
# 744                         Dunkirk
#
#                                               keywords  \
# 0    [{'id': 931, 'name': 'jealousy'}, {'id': 4290,...
# 1    [{'id': 10090, 'name': 'board game'}, {'id': 1...
# 2    [{'id': 642, 'name': 'robbery'}, {'id': 703, '...
# 3    [{'id': 222, 'name': 'schizophrenia'}, {'id': ...
# 4    [{'id': 476, 'name': 'self-fulfilling prophecy...
# ..                                                 ...
# 740  [{'id': 339, 'name': 'submarine'}, {'id': 9663...
# 741  [{'id': 642, 'name': 'robbery'}, {'id': 2076, ...
# 742                [{'id': 190999, 'name': 'minions'}]
# 743  [{'id': 818, 'name': 'based on novel'}, {'id':...
# 744  [{'id': 254, 'name': 'france'}, {'id': 966, 'n...
#
#                                         genre  \
# 0                     Animation Comedy Family
# 1                    Adventure Fantasy Family
# 2                 Action Crime Drama Thriller
# 3             ScienceFiction Thriller Mystery
# 4                      Crime Mystery Thriller
# ..                                        ...
# 740                     Action Crime Thriller
# 741                              Action Crime
# 742  Action Animation Adventure Family Comedy
# 743                  Drama ScienceFiction War
# 744         Action Drama History Thriller War
#
#                                                   cast  \
# 0    [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1    [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2    [{'cast_id': 25, 'character': 'Lt. Vincent Han...
# 3    [{'cast_id': 41, 'character': 'James Cole', 'c...
# 4    [{'cast_id': 17, 'character': 'Detective David...
# ..                                                 ...
# 740  [{'cast_id': 0, 'character': 'Dominic Toretto'...
# 741  [{'cast_id': 9, 'character': 'Baby', 'credit_i...
# 742  [{'cast_id': 0, 'character': 'Gru / Dru (voice...
# 743  [{'cast_id': 6, 'character': 'Caesar', 'credit...
# 744  [{'cast_id': 56, 'character': 'Tommy', 'credit...
#
#                                                   crew
# 0    [{'credit_id': '52fe4284c3a36847f8024f49', 'de...
# 1    [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...
# 2    [{'credit_id': '52fe4292c3a36847f802916d', 'de...
# 3    [{'credit_id': '52fe4212c3a36847f8001ac7', 'de...
# 4    [{'credit_id': '52fe4279c3a36847f802176f', 'de...
# ..                                                 ...
# 740  [{'credit_id': '553ea93f92514138a900b0a5', 'de...
# 741  [{'credit_id': '55c58c009251417a21000e5d', 'de...
# 742  [{'credit_id': '57e71794c3a368222700add6', 'de...
# 743  [{'credit_id': '591f036fc3a368774e036079', 'de...
# 744  [{'credit_id': '598138b5925141519b008a5e', 'de...
#
# [745 rows x 8 columns]

# %%
movies_df['cast'] = movies_df['cast'].apply(lambda x: [i['name'] for i in eval(x)])
movies_df['cast'] = movies_df['cast'].apply(lambda x: ' '.join([i.replace(" ", "") for i in x]))
movies_df['keywords'] = movies_df['keywords'].apply(lambda x: [i['name'] for i in eval(x)])
movies_df['keywords'] = movies_df['keywords'].apply(lambda x: ' '.join([i.replace(" ", "") for i in x]))
movies_df.head()
# Out:
#      id  original_title                                           overview  \
# 0   862       Toy Story  Led by Woody, Andy's toys live happily in his ...
# 1  8844         Jumanji  When siblings Judy and Peter discover an encha...
# 2   949            Heat  Obsessive master thief, Neil McCauley leads a ...
# 3    63  Twelve Monkeys  In the year 2035, convict James Cole reluctant...
# 4   807           Se7en  Two homicide detectives are on a desperate hun...
#
#             title                                           keywords  \
# 0       Toy Story  jealousy toy boy friendship friends rivalry bo...
# 1         Jumanji  boardgame disappearance basedonchildren'sbook ...
# 2            Heat  robbery detective bank obsession chase shootin...
# 3  Twelve Monkeys  schizophrenia philadelphia cassandrasyndrom st...
# 4           Se7en  self-fulfillingprophecy detective s.w.a.t. dru...
#
#                              genre  \
# 0          Animation Comedy Family
# 1         Adventure Fantasy Family
# 2      Action Crime Drama Thriller
# 3  ScienceFiction Thriller Mystery
# 4           Crime Mystery Thriller
#
#                                                 cast  \
# 0  TomHanks TimAllen DonRickles JimVarney Wallace...
# 1  RobinWilliams JonathanHyde KirstenDunst Bradle...
# 2  AlPacino RobertDeNiro ValKilmer JonVoight TomS...
# 3  BruceWillis MadeleineStowe BradPitt Christophe...
# 4  BradPitt MorganFreeman GwynethPaltrow JohnC.Mc...
#
#                                                 crew
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...
# 1  [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...
# 2  [{'credit_id': '52fe4292c3a36847f802916d', 'de...
# 3  [{'credit_id': '52fe4212c3a36847f8001ac7', 'de...
# 4  [{'credit_id': '52fe4279c3a36847f802176f', 'de...

# %%
movies_df['tags'] = movies_df['overview']+' '+movies_df['keywords']+' '
+movies_df['cast']+' '+movies_df['genre']+' '+movies_df['original_title']
# Out:
# 0      TomHanks TimAllen DonRickles JimVarney Wallace...
# 1      RobinWilliams JonathanHyde KirstenDunst Bradle...
# 2      AlPacino RobertDeNiro ValKilmer JonVoight TomS...
# 3      BruceWillis MadeleineStowe BradPitt Christophe...
# 4      BradPitt MorganFreeman GwynethPaltrow JohnC.Mc...
#                              ...
# 740    VinDiesel JasonStatham DwayneJohnson MichelleR...
# 741    AnselElgort LilyJames KevinSpacey JamieFoxx Jo...
# 742    SteveCarell KristenWiig TreyParker MirandaCosg...
# 743    AndySerkis WoodyHarrelson SteveZahn KarinKonov...
# 744    FionnWhitehead TomGlynn-Carney JackLowden Harr...
# Length: 745, dtype: object

# %%
movies_df.drop(['genre', 'original_title', 'keywords', 'cast', 'overview', 'crew'], axis=1, inplace=True)

# %%
movies_df.head()
# Out:
#      id           title                                               tags
# 0   862       Toy Story  Led by Woody, Andy's toys live happily in his ...
# 1  8844         Jumanji  When siblings Judy and Peter discover an encha...
# 2   949            Heat  Obsessive master thief, Neil McCauley leads a ...
# 3    63  Twelve Monkeys  In the year 2035, convict James Cole reluctant...
# 4   807           Se7en  Two homicide detectives are on a desperate hun...

# %%
movies_df.isnull().sum()
movies_df.drop(movies_df[movies_df['tags'].isnull()].index, inplace=True)

# %%
movies_df.shape
# Out:
# (745, 3)

# %%
movies_df.drop_duplicates(inplace=True)
movies_df.head()
# Out:
#      id           title                                               tags
# 0   862       Toy Story  Led by Woody, Andy's toys live happily in his ...
# 1  8844         Jumanji  When siblings Judy and Peter discover an encha...
# 2   949            Heat  Obsessive master thief, Neil McCauley leads a ...
# 3    63  Twelve Monkeys  In the year 2035, convict James Cole reluctant...
# 4   807           Se7en  Two homicide detectives are on a desperate hun...

# %%
movies_df.shape
# Out:
# (740, 3)

# %%
#Import TfIdfVectorizer from scikit-learn
from sklearn.feature_extraction.text import TfidfVectorizer

#Define a TF-IDF Vectorizer Object. Remove all english stop words such as 'the', 'a'
tfidf = TfidfVectorizer(stop_words='english')

#Replace NaN with an empty string
movies_df['tags'] = movies_df['tags'].fillna('')

#Construct the required TF-IDF matrix by fitting and transforming the data
tfidf_matrix = tfidf.fit_transform(movies_df['tags'])

#Output the shape of tfidf_matrix
tfidf_matrix.shape
# Out:
# (740, 10001)

# %%
vectorized_data = tfidf.fit_transform(movies_df['tags'].values)

# %%
# we can dicrease 
from sklearn.decomposition import TruncatedSVD
svd = TruncatedSVD(n_components=3000)

reduced_data = svd.fit_transform(vectorized_dataframe)
reduced_data.shape
# Out:
# (8595, 3000)

# %%
from sklearn.metrics.pairwise import cosine_similarity
similarity = cosine_similarity(reduced_data)

# %%
similarity.shape
# Out:
# (8595, 8595)

# %%
def recomendation_system(movie):
    # find id of movie by its title
    id_of_movie = movies_df[movies_df['title']==movie].index[0]
    # Get the similarity scores of all movies with that movie
    distances = similarity[id_of_movie]
    movie_list = sorted(list(enumerate(distances)), reverse=True, key=lambda x:x[1])[1:15]
    for movie_id in movie_list:
        print(movies_df.iloc[movie_id[0]].title)

# %%
recomendation_system('The Dark Knight Rises')
# Out:
# Flipper
# The Goods: Live Hard, Sell Hard
# Dolphin Tale 2
# Smokey and the Bandit II
# Escape from Planet Earth
# The Cove
# Nine to Five
# 1408
# Alien Abduction
# Ace Ventura: Pet Detective
# Sala samobójców
# Payback
# Little Boy
# In a Heartbeat

# %%
# Import linear_kernel
from sklearn.metrics.pairwise import linear_kernel

# Compute the cosine similarity matrix
cosine_similarity = linear_kernel(tfidf_matrix, tfidf_matrix)

# %%
def get_recommendations(movie, cosine_similarity=cosine_similarity):
    # Get the index of the movie that matches the title
    idx = movies_df[movies_df['title']==movie].index[0]

    # Get the pairwsie similarity scores of all movies with that movie
    sim_scores = list(enumerate(cosine_similarity[idx]))

    # Sort the movies based on the similarity scores
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)

    # Get the scores of the 10 most similar movies
    sim_scores = sim_scores[1:11]

    # Get the movie indices
    movie_indices = [i[0] for i in sim_scores]

    # Return the top 10 most similar movies
    return movies_df['title'].iloc[movie_indices]

# %%
get_recommendations('The Matrix')
# Out:
# 206                The Matrix Revolutions
# 193                   The Matrix Reloaded
# 734                    Ghost in the Shell
# 68                         The Terminator
# 293                 Live Free or Die Hard
# 475                           Cloud Atlas
# 45                  2001: A Space Odyssey
# 567                         Transcendence
# 560                          Interstellar
# 200    Terminator 3: Rise of the Machines
# Name: title, dtype: object

# %%
get_recommendations('Memento')
# Out:
# 212                           50 First Dates
# 213    Eternal Sunshine of the Spotless Mind
# 691                             Finding Dory
# 175                      The Bourne Identity
# 701                             Jason Bourne
# 594                          The Maze Runner
# 28                              Blade Runner
# 211                     The Butterfly Effect
# 245                                 Sin City
# 437                        The Expendables 2
# Name: title, dtype: object
